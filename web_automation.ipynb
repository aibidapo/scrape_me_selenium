# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

# %%
from settings import CHROMEDRIVER_PATH, BOOKSTOSCRAPE_URL

# %%
print(CHROMEDRIVER_PATH)
# Out:
# C:\Users\aibid\OneDrive\STUDIES\PYTHON\WEB SCRAPING\WEB AUTOMATION with SELENIUM WEBDRIVER & PYTHON\webdrivers\chromedriver

# %%
service = Service(executable_path=CHROMEDRIVER_PATH)

# %%
driver = webdriver.Chrome(service=service)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\.pyenv\pyenv-win\versions\3.11.0\Lib\site-packages\selenium\webdriver\common\service.py:71, in Service.start(self)
#      70     cmd.extend(self.command_line_args())
# ---> 71     self.process = subprocess.Popen(cmd, env=self.env,
#      72                                     close_fds=system() != 'Windows',
#      73                                     stdout=self.log_file,
#      74                                     stderr=self.log_file,
#      75                                     stdin=PIPE,
#      76                                     creationflags=self.creationflags)
#      77 except TypeError:
#
# ...

# %%
driver.get(BOOKSTOSCRAPE_URL)

# %%
# driver.get("https://www.google.com")

# %% [markdown]
# ### Locating By CSS Selector

# %%
element1 = driver.find_element(By.CSS_SELECTOR, 'div.alert.alert-warning')

# %%
element1.text
# Out:
# 'Warning! This is a demo website for web scraping purposes. Prices and ratings here were randomly assigned and have no real meaning.'

# %%
element2 = driver.find_element(By.CSS_SELECTOR, 'ul.nav.nav-list')

# %%
element2.text
# Out:
# 'Books\nTravel\nMystery\nHistorical Fiction\nSequential Art\nClassics\nPhilosophy\nRomance\nWomens Fiction\nFiction\nChildrens\nReligion\nNonfiction\nMusic\nDefault\nScience Fiction\nSports and Games\nAdd a comment\nFantasy\nNew Adult\nYoung Adult\nScience\nPoetry\nParanormal\nArt\nPsychology\nAutobiography\nParenting\nAdult Fiction\nHumor\nHorror\nHistory\nFood and Drink\nChristian Fiction\nBusiness\nBiography\nThriller\nContemporary\nSpirituality\nAcademic\nSelf Help\nHistorical\nChristian\nSuspense\nShort Stories\nNovels\nHealth\nPolitics\nCultural\nErotica\nCrime'

# %%
element2.text.split("\n");

# %%
result = element2.text.split("\n")

# %%
result;

# %%
result.sort()

# %%
result;

# %% [markdown]
# #### Search By ID

# %%
element3 = driver.find_element(By.CSS_SELECTOR, 'div#messages')

# %%
element3.text
# Out:
# ''

# %% [markdown]
# #### Search For Images

# %%
image_elements = driver.find_elements(By.CSS_SELECTOR, "img")

# %%
# This gets the individual titles of books

for element in image_elements:
    print(element.get_attribute('alt'))
# Out:
# A Light in the Attic
# Tipping the Velvet
# Soumission
# Sharp Objects
# Sapiens: A Brief History of Humankind
# The Requiem Red
# The Dirty Little Secrets of Getting Your Dream Job
# The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull
# The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics
# The Black Maria
# Starving Hearts (Triangular Trade Trilogy, #1)
# Shakespeare's Sonnets
# Set Me Free
# Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)
# Rip it Up and Start Again
# Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991
# Olio
# Mesaerion: The Best Science Fiction Stories 1800-1849
# Libertarianism for Beginners
# It's Only the Himalayas

# %%
[x.get_attribute('alt') for x in image_elements];

# %% [markdown]
# ##### Using similar method, we can retrieve the links to all books

# %%
image_links = driver.find_elements(By.CSS_SELECTOR, "img")

# %%
for link in image_elements:
    print(element.get_attribute('src'))
# Out:
# https://books.toscrape.com/media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg
# https://books.toscrape.com/media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg
# https://books.toscrape.com/media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg
# https://books.toscrape.com/media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg
# https://books.toscrape.com/media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg
# https://books.toscrape.com/media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg
# https://books.toscrape.com/media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg
# https://books.toscrape.com/media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg
# https://books.toscrape.com/media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg
# https://books.toscrape.com/media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg
# https://books.toscrape.com/media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg
# ...

# %% [markdown]
# ### Task: Print the links and the titles side by side

# %%
books = []

for link in image_elements:
    for element in image_elements:
#         books.append(f"{element.get_attribute('alt')} : {element.get_attribute('src')}")
        print(f"{element.get_attribute('alt')} : {element.get_attribute('src')}\n")
# print(list(enumerate(books)))
# Out:
# A Light in the Attic : https://books.toscrape.com/media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg
#
# Tipping the Velvet : https://books.toscrape.com/media/cache/26/0c/260c6ae16bce31c8f8c95daddd9f4a1c.jpg
#
# Soumission : https://books.toscrape.com/media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg
#
# Sharp Objects : https://books.toscrape.com/media/cache/32/51/3251cf3a3412f53f339e42cac2134093.jpg
#
# Sapiens: A Brief History of Humankind : https://books.toscrape.com/media/cache/be/a5/bea5697f2534a2f86a3ef27b5a8c12a6.jpg
#
# The Requiem Red : https://books.toscrape.com/media/cache/68/33/68339b4c9bc034267e1da611ab3b34f8.jpg
#
# The Dirty Little Secrets of Getting Your Dream Job : https://books.toscrape.com/media/cache/92/27/92274a95b7c251fea59a2b8a78275ab4.jpg
#
# The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull : https://books.toscrape.com/media/cache/3d/54/3d54940e57e662c4dd1f3ff00c78cc64.jpg
#
# ...

# %%
driver.quit()

# %% [markdown]
# ### Locating By ID

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

# %%
from settings import CHROMEDRIVER_PATH, SELENIUM_URL

# %%
service = Service(executable_path=CHROMEDRIVER_PATH)

# %%
driver = webdriver.Chrome(service=service)

# %%
driver.get(SELENIUM_URL)
